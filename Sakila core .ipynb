# %% [markdown]
# # Sakila Core

# %% [markdown]
# # Part 1

# %% [markdown]
# ![png](https://assets.codingdojo.com/boomyeah/company_209/chapter_3569/handouts/chapter3569_5431_sakila-db-model.png)

# %% [markdown]
# ### Loading data and creating engine to run queries

# %%
import pandas as pd
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# %%
username = "root"
password = "Root"
db_name = "sakila-data"
connection = f"mysql+pymysql://{username}:{password}@localhost/{db_name}"

# %%
engine = create_engine(connection)
#type engine to make sure connection worked

# %%
engine
#it works!
# Out:
# Engine(mysql+pymysql://root:***@localhost/sakila-data)

# %% [markdown]
# # Part 2

# %% [markdown]
# ### Now we will execute queries to answer these questions
# 1. What query would you run to get all the customers inside city_id = 312? Your query should return the customers' first name, last name, email, address, and city.
#
# 2. What query would you run to get all comedy films? Note that the genre is called the category in this schema. Your query should return film title, description, release year, rating, and special features.
#
# 3. What query would you run to get all the films that Johnny Lollobrigida was in? Your query should return the actor's last name, film title, and release year.
#
# 4. What query would you run to get the first and last names of all the actors in the movie titled "Bingo Talented"?
#
# 5. What query would you run to get the customer_id associated with all payments greater than twice the average payment amount? (HINT: use 2* in your query to get twice the amount). Your result should include the customer id and the amount.
#
# 6. What query would you run to list the first and last names of the 5 customers who have the highest number(count) of payments? You can title the number of payments as num_payments.

# %%
q = """SELECT DISTINCT c.first_name,last_name,email,address
FROM customer AS c
JOIN address 
ON customer_id = address.address_id
WHERE address.city_id = 312 """
#will figure out why it wont run

# %% [markdown]
# ![sakila%20q1.png](attachment:sakila%20q1.png)

# %%
#"""SELECT title, description, release_year, rating, special_features
FROM film 
JOIN film_category
    WHERE category_id ='comedy';
# Out:
#   Cell In [10], line 2
#     FROM film
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![sakila%20q%202.png](attachment:sakila%20q%202.png)

# %%
SELECT  title, release_year, last_name
FROM film
JOIN film_actor
JOIN actor
     WHERE last_name = 'Lollobrigida'

# %% [markdown]
# ![sakila%20q%203.png](attachment:sakila%20q%203.png)

# %%
SELECT first_name, last_name
FROM actor
JOIN film
   WHERE title='Bingo Talented'

# %% [markdown]
# ![sakila%20q%204.png](attachment:sakila%20q%204.png)

# %%
SELECT customer_id, amount
FROM payment
WHERE amount>
     (SELECT AVG(amount*2)
     FROM payment);

# %% [markdown]
# ![Sakila%20Q5.png](attachment:Sakila%20Q5.png)

# %%
SELECT first_name, last_name
   (SELECT COUNT(*) FROM payment
   WHERE 
FROM payment
JOIN payment

#ORDER BY amount
#WHERE payment_id>
    #(SELECT MAX(amount)
    #FROM payment);

# %% [markdown]
# ![sakila%20q%206.png](attachment:sakila%20q%206.png)
